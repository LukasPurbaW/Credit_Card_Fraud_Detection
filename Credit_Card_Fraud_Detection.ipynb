# %% [markdown]
# <a href="https://colab.research.google.com/github/LukasPurbaW/Credit_Card_Fraud_Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data : https://www.kaggle.com/mlg-ulb/creditcardfraud

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_]default()
drive = GoogleDrive(gauth)
# Out:
#   File "<ipython-input-10-546fb12e5278>", line 12
#     gauth.credentials = GoogleCredentials.get_application_]default()
#                                                           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns

# %%
link = "https://drive.google.com/file/d/1RV0at1IwSHB0aldUMZQh1YGAFCNUCDbE/view?usp=sharing"
id = '1RV0at1IwSHB0aldUMZQh1YGAFCNUCDbE'

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('credit_card_fraud.csv')  
df = pd.read_csv('credit_card_fraud.csv')
df
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ## Data Preprocessing --Handling Missing Values

# %%
df_null = df[df.isna().any(axis=1)]
print(df_null.count())
print("Number of incomplete data :", len(df_null))
print("Percentage of incomplete data:",len(df_null)*100/len(df),"%")
# No missing Value
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# Number of incomplete data : 0
# Percentage of incomplete data: 0.0 %

# %%
sns.countplot(df["Class"]);
print("Number of different element and class")
print(pd.value_counts(df.Class))
print("____________________________________")
# Out:
# Number of different element and class
# 0    284315
# 1       492
# Name: Class, dtype: int64
# ____________________________________
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
